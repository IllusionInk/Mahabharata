# %% [markdown]
# ### Character Arcs of Karna v/s Arjun

# %%
#importing necessary libraries
import io
import pandas as pd
import numpy as np
from pprint import pprint
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#setting graph size
fig_size=[10,5]
plt.rcParams["figure.figsize"] = fig_size

# %%
#reading the megaepic
with io.open ("../Data/mhbhrt/mahafull.txt", encoding ='utf8') as f_in:
    mhb_text = f_in.read()

# %%
mhb_books = mhb_text.split('BOOK')
# BOOK Split as Mahabharata has 18 books.

# %%
# Getting the actual 18 books from the epic.
mhb_book_list = mhb_books[1:]

# %%
# Extracting Book Title
book_titles=[]
for i in range(len(mhb_book_list)):
    book_title = mhb_book_list[i].split("\n")[2].strip()
    book_titles.append(book_title)
book_titles
# Out:
# ['ADI PARVA',
#  'SABHA PARVA',
#  'VANA PARVA',
#  'VIRATA PARVA',
#  'UDYOGA PARVA',
#  'BHISHMA PARVA',
#  'DRONA PARVA',
#  'KARNA-PARVA',
#  'SHALYA-PARVA',
#  'SAUPTIKA-PARVA',
#  'STRI-PARVA',
#  'SANTI PARVA',
#  'ANUSASANA PARVA',
#  'ASWAMEDHA PARVA',
#  'ASRAMAVASIKA PARVA',
#  'MAUSALA-PARVA',
#  'MAHAPRASTHANIKA PARVA',
#  'SVARGAROHANIKA-PARVA']

# %%
characters = ["Arjuna", "Partha", "Dhananjaya", "Gudakesa", "Phalguni", "Vijaya","Savyasachin","Vibhatsu","Kiritin","Jishnu"]

# %%
characters2 = ["Vasusena", "Suta's son","Karna","Radheya","Vrisha"]

# %%
# Counting the occurences of names of Arjun in the epic
counts = ["Book" + '\t' + '\t'.join(characters)]
for i in range(len(mhb_book_list)):
    line = book_titles[i]
    for ch in characters:
        line = line + '\t' + str(mhb_book_list[i].count(ch))
    counts.append(line)

# %%
# type(counts)
counts
# Out:
# ['Book\tArjuna\tPartha\tDhananjaya\tGudakesa\tPhalguni\tVijaya\tSavyasachin\tVibhatsu\tKiritin\tJishnu',
#  'ADI PARVA\t357\t61\t35\t1\t1\t3\t1\t13\t0\t12',
#  'SABHA PARVA\t92\t9\t22\t0\t0\t1\t0\t1\t0\t1',
#  'VANA PARVA\t297\t46\t84\t5\t2\t4\t5\t14\t0\t16',
#  'VIRATA PARVA\t177\t112\t50\t1\t0\t7\t11\t29\t15\t11',
#  'UDYOGA PARVA\t169\t54\t70\t0\t0\t7\t16\t10\t7\t5',
#  'BHISHMA PARVA\t291\t156\t96\t4\t39\t7\t5\t18\t14\t9',
#  'DRONA PARVA\t727\t408\t249\t0\t13\t7\t40\t47\t6\t14',
#  'KARNA-PARVA\t459\t343\t158\t0\t4\t12\t0\t17\t4\t9',
#  'SHALYA-PARVA\t52\t65\t28\t0\t0\t1\t0\t4\t4\t0',
#  'SAUPTIKA-PARVA\t12\t7\t7\t0\t0\t0\t0\t0\t0\t0',
#  'STRI-PARVA\t11\t5\t4\t0\t0\t0\t0\t2\t0\t0',
#  'SANTI PARVA\t69\t23\t16\t0\t0\t0\t0\t0\t0\t4',
#  'ANUSASANA PARVA\t37\t5\t2\t0\t6\t0\t0\t0\t0\t0',
#  'ASWAMEDHA PARVA\t131\t35\t66\t3\t0\t10\t1\t4\t1\t12',
#  'ASRAMAVASIKA PARVA\t24\t2\t3\t0\t0\t2\t0\t3\t0\t1',
#  'MAUSALA-PARVA\t29\t8\t8\t0\t0\t0\t0\t2\t0\t0',
#  'MAHAPRASTHANIKA PARVA\t10\t1\t3\t0\t0\t0\t0\t0\t0\t0',
#  'SVARGAROHANIKA-PARVA\t5\t0\t0\t0\t0\t0\t0\t0\t0\t0']

# %%
with open("../Data/mhb_arjun.txt",'w') as f_out:
    for line in counts:
        f_out.write(line+'\n')

# %%
arj_df = pd.read_csv("../Data/mhb_arjun.txt", sep = '\t')
# arj_df=arj_df.set_index(['Book'])
arj_df['Arjun_names'] = arj_df.sum(1)
arj_df
# Out:
#                      Book  Arjuna  Partha  Dhananjaya  Gudakesa  Phalguni  \
# 0               ADI PARVA     357      61          35         1         1
# 1             SABHA PARVA      92       9          22         0         0
# 2              VANA PARVA     297      46          84         5         2
# 3            VIRATA PARVA     177     112          50         1         0
# 4            UDYOGA PARVA     169      54          70         0         0
# 5           BHISHMA PARVA     291     156          96         4        39
# 6             DRONA PARVA     727     408         249         0        13
# 7             KARNA-PARVA     459     343         158         0         4
# 8            SHALYA-PARVA      52      65          28         0         0
# 9          SAUPTIKA-PARVA      12       7           7         0         0
# 10             STRI-PARVA      11       5           4         0         0
# 11            SANTI PARVA      69      23          16         0         0
# 12        ANUSASANA PARVA      37       5           2         0         6
# 13        ASWAMEDHA PARVA     131      35          66         3         0
# 14     ASRAMAVASIKA PARVA      24       2           3         0         0
# 15          MAUSALA-PARVA      29       8           8         0         0
# 16  MAHAPRASTHANIKA PARVA      10       1           3         0         0
# 17   SVARGAROHANIKA-PARVA       5       0           0         0         0
#
#     Vijaya  Savyasachin  Vibhatsu  Kiritin  Jishnu  Arjun_names
# 0        3            1        13        0      12          484
# 1        1            0         1        0       1          126
# 2        4            5        14        0      16          473
# 3        7           11        29       15      11          413
# 4        7           16        10        7       5          338
# 5        7            5        18       14       9          639
# 6        7           40        47        6      14         1511
# 7       12            0        17        4       9         1006
# 8        1            0         4        4       0          154
# 9        0            0         0        0       0           26
# 10       0            0         2        0       0           22
# 11       0            0         0        0       4          112
# 12       0            0         0        0       0           50
# 13      10            1         4        1      12          263
# 14       2            0         3        0       1           35
# 15       0            0         2        0       0           47
# 16       0            0         0        0       0           14
# 17       0            0         0        0       0            5

# %%
arj_df.plot(legend=True)

# %%
#Counting the occurences of names of Karna in the epic
counts2 = ["Book" + '\t' + '\t'.join(characters2)]
for i in range(len(mhb_book_list)):
    line = book_titles[i]
    for ch in characters2:
        line = line + '\t' + str(mhb_book_list[i].count(ch))
    counts2.append(line)

# %%
counts2
# Out:
# ["Book\tVasusena\tSuta's son\tKarna\tRadheya\tVrisha",
#  'ADI PARVA\t6\t0\t105\t5\t34',
#  'SABHA PARVA\t0\t0\t26\t0\t11',
#  'VANA PARVA\t2\t18\t139\t4\t25',
#  'VIRATA PARVA\t0\t10\t52\t2\t0',
#  'UDYOGA PARVA\t2\t19\t143\t0\t8',
#  'BHISHMA PARVA\t0\t6\t37\t0\t8',
#  'DRONA PARVA\t0\t122\t779\t1\t70',
#  'KARNA-PARVA\t3\t163\t1023\t0\t58',
#  'SHALYA-PARVA\t0\t11\t53\t0\t3',
#  'SAUPTIKA-PARVA\t0\t0\t5\t0\t0',
#  'STRI-PARVA\t0\t0\t24\t0\t4',
#  'SANTI PARVA\t1\t1\t59\t0\t21',
#  'ANUSASANA PARVA\t0\t0\t1\t0\t21',
#  'ASWAMEDHA PARVA\t0\t1\t12\t0\t6',
#  'ASRAMAVASIKA PARVA\t0\t1\t14\t0\t2',
#  'MAUSALA-PARVA\t0\t0\t0\t0\t0',
#  'MAHAPRASTHANIKA PARVA\t0\t0\t0\t0\t0',
#  'SVARGAROHANIKA-PARVA\t0\t0\t12\t0\t0']

# %%
with open("../Data/mhb_karna.txt",'w') as f_out:
    for line in counts2:
        f_out.write(line+'\n')

# %%
krn_df = pd.read_csv("../Data/mhb_karna.txt", sep = '\t')
# krn_df=krn_df.set_index(['Book'])
krn_df['Karna_names'] = krn_df.sum(1)
# type(krn_df)
krn_df
# Out:
#                      Book  Vasusena  Suta's son  Karna  Radheya  Vrisha  \
# 0               ADI PARVA         6           0    105        5      34
# 1             SABHA PARVA         0           0     26        0      11
# 2              VANA PARVA         2          18    139        4      25
# 3            VIRATA PARVA         0          10     52        2       0
# 4            UDYOGA PARVA         2          19    143        0       8
# 5           BHISHMA PARVA         0           6     37        0       8
# 6             DRONA PARVA         0         122    779        1      70
# 7             KARNA-PARVA         3         163   1023        0      58
# 8            SHALYA-PARVA         0          11     53        0       3
# 9          SAUPTIKA-PARVA         0           0      5        0       0
# 10             STRI-PARVA         0           0     24        0       4
# 11            SANTI PARVA         1           1     59        0      21
# 12        ANUSASANA PARVA         0           0      1        0      21
# 13        ASWAMEDHA PARVA         0           1     12        0       6
# 14     ASRAMAVASIKA PARVA         0           1     14        0       2
# 15          MAUSALA-PARVA         0           0      0        0       0
# 16  MAHAPRASTHANIKA PARVA         0           0      0        0       0
# 17   SVARGAROHANIKA-PARVA         0           0     12        0       0
#
#     Karna_names
# 0           150
# 1            37
# 2           188
# 3            64
# 4           172
# 5            51
# 6           972
# 7          1247
# 8            67
# 9             5
# 10           28
# 11           82
# 12           22
# 13           19
# 14           17
# 15            0
# 16            0
# 17           12

# %%
chars_df=pd.merge(arj_df,krn_df,on='Book')
chars_df
charsdf_final = chars_df[['Book','Arjun_names','Karna_names']]
charsdf_final
# Out:
#                      Book  Arjun_names  Karna_names
# 0               ADI PARVA          484          150
# 1             SABHA PARVA          126           37
# 2              VANA PARVA          473          188
# 3            VIRATA PARVA          413           64
# 4            UDYOGA PARVA          338          172
# 5           BHISHMA PARVA          639           51
# 6             DRONA PARVA         1511          972
# 7             KARNA-PARVA         1006         1247
# 8            SHALYA-PARVA          154           67
# 9          SAUPTIKA-PARVA           26            5
# 10             STRI-PARVA           22           28
# 11            SANTI PARVA          112           82
# 12        ANUSASANA PARVA           50           22
# 13        ASWAMEDHA PARVA          263           19
# 14     ASRAMAVASIKA PARVA           35           17
# 15          MAUSALA-PARVA           47            0
# 16  MAHAPRASTHANIKA PARVA           14            0
# 17   SVARGAROHANIKA-PARVA            5           12

# %%
characters3 = ["Duryodhana", "Dussasana","Duhshasana","Sakuni","Shakuni"]

# %%
krn_assoc = chars_df[['Book','Karna_names']]
krn_assoc

# %% [markdown]
# ### Plotting the appearances of Karna and Arjun

# %% [markdown]
# #### Sharp rise in chapter 6,7 as Karna is at the front of the war, leads the battle in book 7 and faces Arjun in the battlefield

# %%
 # fig, axes = plt.subplots(nrows=1, ncols=2)
charsdf_final.plot(legend=True, kind='bar')
